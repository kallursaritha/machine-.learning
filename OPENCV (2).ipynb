# %%
#import libraries
import numpy as np
from matplotlib import pyplot as plt
import cv2

# %%
# Python code to read image
img1 = cv2.imread(r"2-500x250-2.jpg")

plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
plt.title("colours - original color image")
# Out:
# Text(0.5, 1.0, 'colours - original color image')

# %%
# Using 0 to read image in grayscale mode
gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

plt.imshow(gray, cmap = 'gray')
plt.title("colour- gray")
# Out:
# Text(0.5, 1.0, 'colour- gray')

# %%
# resize() function takes 2 parameters, 
# the image and the dimensions
image = cv2.imread(r"2-500x250-2.jpg")

# Loading the image
half = cv2.resize(image, (0, 0), fx = 0.1, fy = 0.1)
bigger = cv2.resize(image, (1000, 900))
 
Titles =["Original", "Half", "Bigger"]
images =[image, half, bigger]
count = 3
 
for i in range(count):
    plt.subplot(2, 2, i + 1)
    plt.title(Titles[i])
    plt.imshow(images[i])
 
    plt.show()

# %%
# Display the blurred image
Gaussian = cv2.GaussianBlur(img1, (7, 7), 0)
cv2.imshow('Gaussian Blurring', Gaussian)
cv2.waitKey(0)

plt.imshow(Gaussian)
plt.show()

# %%
# Detect edges in the image using Canny edge detection
edges = cv2.Canny(gray, 50, 150)
# Display the edges
cv2.imshow('Edges', edges)

plt.imshow(edges)
plt.show()

# %%
img2 = cv2.imread(r'1-500x250-3.jpg')

plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
plt.title("colours - original color image")
# Out:
# Text(0.5, 1.0, 'colours - original color image')

# %%
# arithmetic operation of
# addition of two images
 
img1 = cv2.imread(r'2-500x250-2.jpg') 
img2 = cv2.imread(r'1-500x250-3.jpg')

# cv2.addWeighted is applied over the
# image inputs with applied parameters
weightedSum = cv2.addWeighted(img1, 0.6, img2, 0.4, 0)
  
# the window showing output image
# with the weighted sum 
cv2.imshow('Weighted Image', weightedSum)
  
# De-allocate any associated memory usage  
if cv2.waitKey(0) & 0xff == 27: 
    cv2.destroyAllWindows() 
    
plt.imshow(weightedSum)
plt.show()

# %%
# path to input images are specified and  
# images are loaded with imread command 
img1 = cv2.imread(r'1-500x250-3.jpg') 
img2 = cv2.imread(r'2-500x250-2.jpg')
  
# cv2.subtract is applied over the
# image inputs with applied parameters
sub = cv2.subtract(img1, img2)
  
# the window showing output image
# with the subtracted image 
cv2.imshow('Subtracted Image', sub)
  
# De-allocate any associated memory usage  
if cv2.waitKey(0) & 0xff == 27: 
    cv2.destroyAllWindows() 
    
plt.imshow(sub)
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt
  
  
# Opening image
img = cv2.imread("stop.png")
  
# OpenCV opens images as BRG 
# but we want it as RGB and 
# we also need a grayscale 
# version
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  
# Creates the environment 
# of the picture and shows it
plt.subplot(1, 1, 1)
plt.imshow(img_rgb)
plt.show()

# %%
# Use minSize because for not 
# bothering with extra-small 
# dots that would look like STOP signs
found = data.detectMultiScale(img_gray, 
                                   minSize =(20, 20))
  
# Don't do anything if there's 
# no sign
amount_found = len(found)
  
  
if amount_found != 0:
      
    # There may be more than one
    # sign in the image
    for (x, y, width, height) in found:
          
        # We draw a green rectangle around
        # every recognized sign
        cv2.rectangle(img_rgb, (x, y), 
                      (x + height, y + width), 
                      (0, 255, 0), 5)

# %%
import cv2
from matplotlib import pyplot as plt
  
# Opening image
img = cv2.imread("stop.png")
  
# OpenCV opens images as BRG 
# but we want it as RGB We'll 
# also need a grayscale version
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  
  
# Use minSize because for not 
# bothering with extra-small 
# dots that would look like STOP signs
data = cv2.CascadeClassifier('stop_data[1].xml')
  
found = data.detectMultiScale(img_gray, 
                                   minSize =(20, 20))
  
# Don't do anything if there's 
# no sign
amount_found = len(found)
  
if amount_found != 0:
      
    # There may be more than one
    # sign in the image
    for (x, y, width, height) in found:
          
        # We draw a green rectangle around
        # every recognized sign
        cv2.rectangle(img_rgb, (x, y), 
                      (x + height, y + width), 
                      (0, 255, 0), 5)
          
# Creates the environment of 
# the picture and shows it
plt.subplot(1, 1, 1)
plt.imshow(img_rgb)
plt.show()
